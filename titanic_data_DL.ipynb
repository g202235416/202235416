# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv("C:/Users/a/Downloads/titanic/test.csv",index_col= 0)
df_train = pd.read_csv("C:/Users/a/Downloads/titanic/train.csv", index_col=0)
df_data = pd.concat([df_train, df_test], axis=0)
df_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df = df_data.drop(columns=['Name', 'Ticket', 'Cabin', 'Embarked'], axis=1)
df = df.dropna(axis=0)
df.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# PassengerId
# 1                 0.0       3    male  22.0      1      0   7.2500
# 2                 1.0       1  female  38.0      1      0  71.2833
# 3                 1.0       3  female  26.0      0      0   7.9250
# 4                 1.0       1  female  35.0      1      0  53.1000
# 5                 0.0       3    male  35.0      0      0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
X = df.iloc[:,1:7].values
y = df.iloc[:,0].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values


from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(100,input_shape=(6,),activation='relu'))
model.add(Dense(80,activation='relu'))
model.add(Dense(60,activation='relu'))
model.add(Dense(2,activation='softmax'))

model.compile(Adam(lr=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 100)               700
#
#  dense_13 (Dense)            (None, 80)                8080
#
#  dense_14 (Dense)            (None, 60)                4860
#
#  dense_15 (Dense)            (None, 2)                 122
#
# ...
# Total params: 13,762
# Trainable params: 13,762
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\a\anaconda3\lib\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=100, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 9ms/step - loss: 3.2835 - accuracy: 0.5867 - val_loss: 0.6815 - val_accuracy: 0.5804
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6585 - accuracy: 0.6602 - val_loss: 0.6366 - val_accuracy: 0.6154
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6099 - accuracy: 0.6655 - val_loss: 0.6217 - val_accuracy: 0.6713
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.6725 - val_loss: 0.6733 - val_accuracy: 0.6783
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.6865 - val_loss: 0.5859 - val_accuracy: 0.7343
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5694 - accuracy: 0.7005 - val_loss: 0.5625 - val_accuracy: 0.6573
# Epoch 7/100
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83        79
#            1       0.79      0.78      0.79        64
#
#     accuracy                           0.81       143
#    macro avg       0.81      0.81      0.81       143
# weighted avg       0.81      0.81      0.81       143
#
# [[66 13]
#  [14 50]]
