# %%
import warnings
warnings.filterwarnings(action = 'ignore')
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

breast_cancer_data = load_breast_cancer()
df_data = pd.DataFrame(breast_cancer_data.data, columns = breast_cancer_data.feature_names)
df_labels = pd.DataFrame(breast_cancer_data.target, columns = ['label'])

# %%
df_data
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df_data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df_data.isnull()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          False         False           False      False            False
# 1          False         False           False      False            False
# 2          False         False           False      False            False
# 3          False         False           False      False            False
# 4          False         False           False      False            False
# ..           ...           ...             ...        ...              ...
# 564        False         False           False      False            False
# 565        False         False           False      False            False
# 566        False         False           False      False            False
# 567        False         False           False      False            False
# 568        False         False           False      False            False
#
# ...

# %%
df_data.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
df = pd.concat([df_data, df_labels], axis = 1)
df[10:20]
# Out:
#     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 10        16.02         23.24          102.70      797.8          0.08206
# 11        15.78         17.89          103.60      781.0          0.09710
# 12        19.17         24.80          132.40     1123.0          0.09740
# 13        15.85         23.95          103.70      782.7          0.08401
# 14        13.73         22.61           93.60      578.3          0.11310
# 15        14.54         27.54           96.73      658.8          0.11390
# 16        14.68         20.13           94.74      684.5          0.09867
# 17        16.13         20.68          108.10      798.8          0.11700
# 18        19.81         22.15          130.00     1260.0          0.09831
# 19        13.54         14.36           87.46      566.3          0.09779
#
#     mean compactness  mean concavity  mean concave points  mean symmetry  \
# 10           0.06669         0.03299              0.03323         0.1528
# ...

# %%
sns.scatterplot(x = 'worst area', y = 'mean radius',hue = 'label', data = df)
# Out:
# <AxesSubplot:xlabel='worst area', ylabel='mean radius'>

# %%
sns.countplot(x='label', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
sns.displot(data = df, x = 'mean symmetry', hue='label', col = 'label')

# %%
sns.catplot(x='mean area',col = 'label',data = df, kind = 'box')

# %%
print(breast_cancer_data.target_names)
# Out:
# ['malignant' 'benign']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_data, df_labels, test_size=0.2,stratify = df_labels, random_state=1)

print("X_train.shape :", X_train.shape)

print("y_train.shape :", y_train.shape)

print("X_test.shape:", X_test.shape)

print("y_test.shape:", y_test.shape)
# Out:
# X_train.shape : (455, 30)
# y_train.shape : (455, 1)
# X_test.shape: (114, 30)
# y_test.shape: (114, 1)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
mymodel = KNeighborsClassifier(n_neighbors=3)
mymodel.fit(X_train, y_train)
prediction = mymodel.predict(X_test)
mymodel.score(X_test, y_test)
# Out:
# 0.9736842105263158
